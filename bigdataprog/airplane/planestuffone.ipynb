# %%
import pandas as pd


nyc = pd.read_csv("cleaneddata\Motor_Vehicle_Collisions_-_Crashescleaned.csv")
nyc
# Out:
#          CRASH DATE   BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0         9/11/2021       NaN       NaN        NaN        NaN
# 1         3/26/2022       NaN       NaN        NaN        NaN
# 2         6/29/2022       NaN       NaN        NaN        NaN
# 3         9/11/2021  BROOKLYN   11208.0  40.667202 -73.866500
# 4        12/14/2021  BROOKLYN   11233.0  40.683304 -73.917274
# ...             ...       ...       ...        ...        ...
# 1048570    9/3/2016       NaN       NaN  40.678097 -73.941666
# 1048571   8/20/2016       NaN       NaN  40.736774 -73.984260
# 1048572   8/26/2016    QUEENS   11694.0  40.579975 -73.855255
# 1048573   9/14/2016    QUEENS   11422.0  40.635880 -73.740204
# 1048574   8/20/2016  BROOKLYN   11216.0  40.686092 -73.950730
#
#                         LOCATION  NUMBER OF PERSONS INJURED  \
# 0                            NaN                        2.0
# 1                            NaN                        1.0
# ...

# %%
casualties = nyc.iloc[:, 7:15]

casualties
# Out:
#          NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# 0                             0.0                              0
# 1                             0.0                              0
# 2                             0.0                              0
# 3                             0.0                              0
# 4                             0.0                              0
# ...                           ...                            ...
# 1048570                       0.0                              0
# 1048571                       0.0                              0
# 1048572                       0.0                              0
# 1048573                       0.0                              0
# 1048574                       0.0                              0
#
#          NUMBER OF PEDESTRIANS KILLED  NUMBER OF CYCLIST INJURED  \
# 0                                   0                          0
# ...

# %%
deaths = casualties[casualties["NUMBER OF PERSONS KILLED"] > 0]
deaths
# Out:
#          NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# 39                            1.0                              0
# 148                           1.0                              0
# 591                           1.0                              0
# 605                           1.0                              0
# 1320                          1.0                              0
# ...                           ...                            ...
# 1041580                       1.0                              0
# 1042446                       1.0                              0
# 1042786                       1.0                              0
# 1045897                       1.0                              0
# 1046019                       1.0                              0
#
#          NUMBER OF PEDESTRIANS KILLED  NUMBER OF CYCLIST INJURED  \
# 39                                  1                          0
# ...

# %%
deaths = casualties[casualties["NUMBER OF PERSONS KILLED"] > 1]
deaths
# Out:
#         NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# 4138                         2.0                              0
# 22641                        2.0                              0
# 23325                        3.0                              0
# 24994                        2.0                              0
# 44652                        2.0                              0
# 60734                        2.0                              0
# 66812                        2.0                              0
# 111290                       2.0                              0
# 114157                       3.0                              0
# 114218                       2.0                              0
# 115364                       2.0                              0
# 118155                       3.0                              0
# 128633                       2.0                              0
# 140093                       2.0                              0
# ...

# %%
iowa = pd.read_csv("cleaneddata\Crashes_in_Iowa_by_Severity_and_Day_20240403.csv")
iowa
# Out:
#       Date of Crash        Crash Severity  Crashes  Unnamed: 3  Unnamed: 4  \
# 0          1/1/2009  Property Damage Only       66         NaN         NaN
# 1          1/1/2009          Minor Injury       10         NaN         NaN
# 2          1/1/2009      Possible/Unknown        7         NaN         NaN
# 3          1/1/2009          Major Injury        2         NaN         NaN
# 4          1/2/2009          Minor Injury        8         NaN         NaN
# ...             ...                   ...      ...         ...         ...
# 24974     3/20/2024          Minor Injury        5         NaN         NaN
# 24975     3/21/2024          Minor Injury        4         NaN         NaN
# 24976     3/21/2024          Major Injury        1         NaN         NaN
# 24977     3/21/2024  Property Damage Only       11         NaN         NaN
# 24978     3/21/2024      Possible/Unknown        1         NaN         NaN
#
#        Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# ...

# %%
minor = iowa[iowa["Crash Severity"] == "Minor Injury"]
minor
# Out:
#       Date of Crash Crash Severity  Crashes  Unnamed: 3  Unnamed: 4  \
# 1          1/1/2009   Minor Injury       10         NaN         NaN
# 4          1/2/2009   Minor Injury        8         NaN         NaN
# 8          1/3/2009   Minor Injury       36         NaN         NaN
# 14         1/4/2009   Minor Injury       20         NaN         NaN
# 21         1/5/2009   Minor Injury       10         NaN         NaN
# ...             ...            ...      ...         ...         ...
# 24964     3/17/2024   Minor Injury        6         NaN         NaN
# 24967     3/18/2024   Minor Injury        5         NaN         NaN
# 24970     3/19/2024   Minor Injury        7         NaN         NaN
# 24974     3/20/2024   Minor Injury        5         NaN         NaN
# 24975     3/21/2024   Minor Injury        4         NaN         NaN
#
#        Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 1             NaN         NaN         NaN         NaN
# ...

# %%
major = iowa[iowa["Crash Severity"] == "Major Injury"]
major
# Out:
#       Date of Crash Crash Severity  Crashes  Unnamed: 3  Unnamed: 4  \
# 3          1/1/2009   Major Injury        2         NaN         NaN
# 6          1/2/2009   Major Injury        1         NaN         NaN
# 10         1/3/2009   Major Injury        5         NaN         NaN
# 15         1/4/2009   Major Injury        3         NaN         NaN
# 22         1/5/2009   Major Injury        3         NaN         NaN
# ...             ...            ...      ...         ...         ...
# 24953     3/15/2024   Major Injury        3         NaN         NaN
# 24958     3/16/2024   Major Injury        2         NaN         NaN
# 24961     3/17/2024   Major Injury        1         NaN         NaN
# 24968     3/18/2024   Major Injury        2         NaN         NaN
# 24976     3/21/2024   Major Injury        1         NaN         NaN
#
#        Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 3             NaN         NaN         NaN         NaN
# ...

# %%
transit = pd.read_csv("cleaneddata\Daily_Transit_Ridership.csv")
transit
# Out:
#                       Agency     Mode        Date  Week Number  \
# 0         WMATA Bus and Rail  Transit  06/05/2022           24
# 1         WMATA Bus and Rail  Transit  06/06/2022           24
# 2         WMATA Bus and Rail  Transit  06/07/2022           24
# 3         WMATA Bus and Rail  Transit  06/08/2022           24
# 4         WMATA Bus and Rail  Transit  06/09/2022           24
# ..                       ...      ...         ...          ...
# 206  San Francisco BART Rail  Transit  08/30/2022           36
# 207  San Francisco BART Rail  Transit  08/31/2022           36
# 208  San Francisco BART Rail  Transit  09/01/2022           36
# 209  San Francisco BART Rail  Transit  09/02/2022           36
# 210  San Francisco BART Rail  Transit  09/03/2022           36
#
#      Current Ridership  Year
# 0               266000  2022
# 1               506000  2022
# 2               536000  2022
# 3               551000  2022
# 4               539000  2022
# ...

# %%
nyct = transit[transit["Agency"] == "New York City MTA Rail"]
nyct
# Out:
#                     Agency     Mode        Date  Week Number  \
# 7   New York City MTA Rail  Transit  06/25/2022           27
# 8   New York City MTA Rail  Transit  06/26/2022           27
# 9   New York City MTA Rail  Transit  06/27/2022           27
# 10  New York City MTA Rail  Transit  06/28/2022           27
# 11  New York City MTA Rail  Transit  06/29/2022           27
# ..                     ...      ...         ...          ...
# 66  New York City MTA Rail  Transit  08/23/2022           35
# 67  New York City MTA Rail  Transit  08/24/2022           35
# 68  New York City MTA Rail  Transit  08/25/2022           35
# 69  New York City MTA Rail  Transit  08/26/2022           35
# 70  New York City MTA Rail  Transit  08/27/2022           35
#
#     Current Ridership  Year
# 7             2287013  2022
# 8             2012595  2022
# 9             2938858  2022
# 10            3255241  2022
# 11            3256053  2022
# ..                ...   ...
# ...

# %%
avg = nyct["Current Ridership"].mean()
avg

#Iowa has 1,119,070 registered cars
#
# Out:
# 2654728.4375
