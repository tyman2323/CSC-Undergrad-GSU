# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as mp
df = pd.read_csv("C:\\Users\\Ayman\\Documents\\machinelearning\\hw1bonus\\ionosphere.csv")#insert absolute dataset path here with \\ for the \
df
# Out:
#      at1  at2      at3      at4      at5      at6      at7      at8      at9  \
# 0      1    0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 1      1    0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 2      1    0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 3      1    0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 4      1    0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
# ..   ...  ...      ...      ...      ...      ...      ...      ...      ...
# 346    1    0  0.83508  0.08298  0.73739 -0.14706  0.84349 -0.05567  0.90441
# 347    1    0  0.95113  0.00419  0.95183 -0.02723  0.93438 -0.01920  0.94590
# 348    1    0  0.94701 -0.00034  0.93207 -0.03227  0.95177 -0.03431  0.95584
# 349    1    0  0.90608 -0.01657  0.98122 -0.01989  0.95691 -0.03646  0.85746
# 350    1    0  0.84710  0.13533  0.73638 -0.06151  0.87873  0.08260  0.88928
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 35 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   at1     351 non-null    int64
#  1   at2     351 non-null    int64
#  2   at3     351 non-null    float64
#  3   at4     351 non-null    float64
#  4   at5     351 non-null    float64
#  5   at6     351 non-null    float64
#  6   at7     351 non-null    float64
#  7   at8     351 non-null    float64
#  8   at9     351 non-null    float64
#  9   at10    351 non-null    float64
#  10  at11    351 non-null    float64
#  11  at12    351 non-null    float64
#  12  at13    351 non-null    float64
#  13  at14    351 non-null    float64
#  14  at15    351 non-null    float64
#  15  at16    351 non-null    float64
#  16  at17    351 non-null    float64
#  17  at18    351 non-null    float64
#  18  at19    351 non-null    float64
#  19  at20    351 non-null    float64
#  20  at21    351 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# at1     0
# at2     0
# at3     0
# at4     0
# at5     0
# at6     0
# at7     0
# at8     0
# at9     0
# at10    0
# at11    0
# at12    0
# at13    0
# at14    0
# at15    0
# at16    0
# at17    0
# at18    0
# at19    0
# at20    0
# at21    0
# at22    0
# at23    0
# at24    0
# at25    0
# at26    0
# at27    0
# at28    0
# at29    0
# at30    0
# at31    0
# at32    0
# at33    0
# at34    0
# at35    0
# dtype: int64

# %%
df.nunique()
# Out:
# at1       2
# at2       1
# at3     219
# at4     269
# at5     204
# at6     259
# at7     231
# at8     260
# at9     244
# at10    267
# at11    246
# at12    269
# at13    238
# at14    266
# at15    234
# at16    270
# at17    254
# at18    280
# at19    254
# at20    266
# at21    248
# at22    265
# at23    248
# at24    264
# at25    256
# at26    273
# at27    256
# at28    281
# at29    244
# at30    266
# at31    243
# at32    263
# at33    245
# at34    263
# at35      2
# dtype: int64

# %%
sns.heatmap(df.corr(numeric_only = True), annot = True)
mp.rcParams['figure.figsize'] = (60,7)
mp.show()
