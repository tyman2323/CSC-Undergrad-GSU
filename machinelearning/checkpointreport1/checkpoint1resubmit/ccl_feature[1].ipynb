# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"/Users/sadiaakther/Desktop/Machin Learning/Drug_response/ccl_feature_original.csv")
df
# Out:
#       Unnamed: 0  LN18_CENTRAL_NERVOUS_SYSTEM  769P_KIDNEY  786O_KIDNEY  \
# 0          DDX25                     4.996216     4.147237     4.017600
# 1          CTBP1                    10.265250    10.114860    10.238600
# 2          MYOM2                     4.708651     6.390774     5.031673
# 3          TRPM3                     3.980366     4.205438     4.346737
# 4          ZNF41                     4.426134     4.733746     4.489790
# ...          ...                          ...          ...          ...
# 14707     FBXO41                     6.062612     4.436497     6.124247
# 14708    CCDC160                     3.413142     3.703556     3.607508
# 14709    ZFAND2A                     9.068371     9.848369     9.156413
# 14710       DPH5                     8.554929     8.382317     8.188525
# 14711     HECTD2                     6.700492     8.061579     7.320557
#
#        CAOV3_OVARY  HEPG2_LIVER  MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'LN18_CENTRAL_NERVOUS_SYSTEM', '769P_KIDNEY',
#        '786O_KIDNEY', 'CAOV3_OVARY', 'HEPG2_LIVER',
#        'MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE', 'NCIH524_LUNG',
#        'NCIH209_LUNG', 'MIAPACA2_PANCREAS',
#        ...
#        'SLR21_KIDNEY', 'LNZ308_CENTRAL_NERVOUS_SYSTEM',
#        'LN340_CENTRAL_NERVOUS_SYSTEM', 'HCC827GR5_LUNG', 'SLR20_KIDNEY',
#        'HK2_KIDNEY', 'EW8_BONE', 'UOK101_KIDNEY', 'JHESOAD1_OESOPHAGUS',
#        'CH157MN_CENTRAL_NERVOUS_SYSTEM'],
#       dtype='object', length=1038)

# %%
df.head(7)
# Out:
#   Unnamed: 0  LN18_CENTRAL_NERVOUS_SYSTEM  769P_KIDNEY  786O_KIDNEY  \
# 0      DDX25                     4.996216     4.147237     4.017600
# 1      CTBP1                    10.265250    10.114860    10.238600
# 2      MYOM2                     4.708651     6.390774     5.031673
# 3      TRPM3                     3.980366     4.205438     4.346737
# 4      ZNF41                     4.426134     4.733746     4.489790
# 5       URI1                     9.485630     9.615246     9.251918
# 6        CPE                     9.638608     4.714296     5.813144
#
#    CAOV3_OVARY  HEPG2_LIVER  MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  \
# 0     4.301526     4.567166                                  5.587113
# 1    10.950850    10.168080                                 10.872280
# 2     4.948869     4.107366                                  7.200759
# 3     4.095896     4.084358                                  4.147885
# 4     5.407978     4.579864                                  5.708549
# ...

# %%
df.shape
# Out:
# (14712, 1038)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                        0
# LN18_CENTRAL_NERVOUS_SYSTEM       0
# 769P_KIDNEY                       0
# 786O_KIDNEY                       0
# CAOV3_OVARY                       0
#                                  ..
# HK2_KIDNEY                        0
# EW8_BONE                          0
# UOK101_KIDNEY                     0
# JHESOAD1_OESOPHAGUS               0
# CH157MN_CENTRAL_NERVOUS_SYSTEM    0
# Length: 1038, dtype: int64

# %%
df.boxplot
# Out:
# <bound method boxplot_frame of       Unnamed: 0  LN18_CENTRAL_NERVOUS_SYSTEM  769P_KIDNEY  786O_KIDNEY  \
# 0          DDX25                     4.996216     4.147237     4.017600
# 1          CTBP1                    10.265250    10.114860    10.238600
# 2          MYOM2                     4.708651     6.390774     5.031673
# 3          TRPM3                     3.980366     4.205438     4.346737
# 4          ZNF41                     4.426134     4.733746     4.489790
# ...          ...                          ...          ...          ...
# 14707     FBXO41                     6.062612     4.436497     6.124247
# 14708    CCDC160                     3.413142     3.703556     3.607508
# 14709    ZFAND2A                     9.068371     9.848369     9.156413
# 14710       DPH5                     8.554929     8.382317     8.188525
# 14711     HECTD2                     6.700492     8.061579     7.320557
#
# ...

# %%
df.nunique()
# Out:
# Unnamed: 0                        14712
# LN18_CENTRAL_NERVOUS_SYSTEM       14400
# 769P_KIDNEY                       14333
# 786O_KIDNEY                       14346
# CAOV3_OVARY                       14364
#                                   ...
# HK2_KIDNEY                        14387
# EW8_BONE                          14381
# UOK101_KIDNEY                     14392
# JHESOAD1_OESOPHAGUS               14340
# CH157MN_CENTRAL_NERVOUS_SYSTEM    14343
# Length: 1038, dtype: int64

# %%
df.count()
df.describe()
# Out:
#        LN18_CENTRAL_NERVOUS_SYSTEM   769P_KIDNEY   786O_KIDNEY   CAOV3_OVARY  \
# count                 14712.000000  14712.000000  14712.000000  14712.000000
# mean                      6.602886      6.571304      6.600111      6.650794
# std                       2.486791      2.460877      2.473522      2.443350
# min                       3.146447      3.115263      2.991723      3.109007
# 25%                       4.253728      4.300617      4.293450      4.373747
# 50%                       6.304580      6.136252      6.174608      6.357756
# 75%                       8.517424      8.475683      8.514780      8.446608
# max                      14.774330     14.744250     14.765750     14.883320
#
#         HEPG2_LIVER  MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  NCIH524_LUNG  \
# count  14712.000000                              14712.000000  14712.000000
# mean       6.626715                                  6.579910      6.602024
# ...

# %%
ln = df['LN18_CENTRAL_NERVOUS_SYSTEM']
P = df['769P_KIDNEY']
fig = plt.figure()
ax = fig.add_axes([0.1, 0.6, 2.5, 2.4])
ax.set_xlabel("LN18_CENTRAL_NERVOUS_SYSTEM")
ax.set_ylabel("769P_KIDNEY")
ax.scatter(ln,P)

# %%
ln2 = df['786O_KIDNEY']
P2 = df['CAOV3_OVARY']
fig = plt.figure()
ax = fig.add_axes([0.1, 0.6, 2.5, 2.4])
ax.set_xlabel("786O_KIDNEY")
ax.set_ylabel("CAOV3_OVARY")
ax.scatter(ln2,P2)

# %%
ln3 = df['CH157MN_CENTRAL_NERVOUS_SYSTEM']
P3 = df['HEPG2_LIVER']
fig = plt.figure()
ax = fig.add_axes([0.1, 0.6, 2.5, 2.4])
ax.set_xlabel("CH157MN_CENTRAL_NERVOUS_SYSTEM")
ax.set_ylabel("HEPG2_LIVER")
ax.scatter(ln3,P3)

# %% [markdown]
# this graph should the relationship between the variables LN18 and 769P. The is no correlation of this graph. There appears to be no discernible pattern or significant link between the two variables when the dots are dispersed randomly.
