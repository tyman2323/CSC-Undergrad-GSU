# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"drug_embedding.csv")
df
# Out:
#      cabozantinib  nakiterpiosin   MST-312   GSK4112     ML258  belinostat  \
# 0        0.001636       0.005619 -0.043111  0.001764 -0.007501   -0.004327
# 1        0.009475       0.064310  0.051800 -0.102087  0.046719    0.269502
# 2       -0.121793       0.089949  0.125069  0.116982  0.134672   -0.060709
# 3       -0.026582      -0.157011  0.402590  0.022947 -0.148376    0.268936
# 4       -0.090666      -0.006984 -0.248655  0.013360 -0.116712    0.135426
# ..            ...            ...       ...       ...       ...         ...
# 295      0.007834      -0.015357 -0.098144 -0.030257  0.004565   -0.028087
# 296     -0.094815       0.031447 -0.040429 -0.173176 -0.031357    0.235188
# 297     -0.039226       0.006915 -0.021440  0.098243  0.249433   -0.084452
# 298      0.021458      -0.117484  0.299413 -0.095095  0.108865    0.031053
# 299     -0.001357      -0.032845  0.165557 -0.095092  0.123183    0.200369
#
# ...

# %%
df.columns
# Out:
# Index(['cabozantinib', 'nakiterpiosin', 'MST-312', 'GSK4112', 'ML258',
#        'belinostat', 'GSK525762A', 'foretinib', 'ML050', 'selumetinib',
#        ...
#        'BRD8958', 'KU-60019', 'Ki8751', 'bexarotene', 'GMX-1778',
#        'BRD-K02492147', 'methotrexate', 'importazole', 'BRD-K45681478',
#        'BMS-536924'],
#       dtype='object', length=483)

# %%
df.head(7)
# Out:
#    cabozantinib  nakiterpiosin   MST-312   GSK4112     ML258  belinostat  \
# 0      0.001636       0.005619 -0.043111  0.001764 -0.007501   -0.004327
# 1      0.009475       0.064310  0.051800 -0.102087  0.046719    0.269502
# 2     -0.121793       0.089949  0.125069  0.116982  0.134672   -0.060709
# 3     -0.026582      -0.157011  0.402590  0.022947 -0.148376    0.268936
# 4     -0.090666      -0.006984 -0.248655  0.013360 -0.116712    0.135426
# 5     -0.056967       0.001206  0.012582  0.084937  0.072102   -0.119144
# 6      0.013596       0.019163  0.010251  0.007187  0.020498   -0.003249
#
#    GSK525762A  foretinib     ML050  selumetinib  ...   BRD8958  KU-60019  \
# 0   -0.006929  -0.000840 -0.020640    -0.014775  ... -0.035379 -0.026682
# 1   -0.019258  -0.013944  0.008432    -0.027050  ... -0.090584 -0.048360
# 2   -0.000178  -0.172189  0.444812     0.148657  ...  0.072976 -0.019486
# 3   -0.138640   0.009315  0.229033    -0.038763  ...  0.102617 -0.041635
# ...

# %%
df.isnull().sum()
# Out:
# cabozantinib     0
# nakiterpiosin    0
# MST-312          0
# GSK4112          0
# ML258            0
#                 ..
# BRD-K02492147    0
# methotrexate     0
# importazole      0
# BRD-K45681478    0
# BMS-536924       0
# Length: 483, dtype: int64

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.boxplot
# Out:
# <bound method boxplot_frame of      cabozantinib  nakiterpiosin   MST-312   GSK4112     ML258  belinostat  \
# 0        0.001636       0.005619 -0.043111  0.001764 -0.007501   -0.004327
# 1        0.009475       0.064310  0.051800 -0.102087  0.046719    0.269502
# 2       -0.121793       0.089949  0.125069  0.116982  0.134672   -0.060709
# 3       -0.026582      -0.157011  0.402590  0.022947 -0.148376    0.268936
# 4       -0.090666      -0.006984 -0.248655  0.013360 -0.116712    0.135426
# ..            ...            ...       ...       ...       ...         ...
# 295      0.007834      -0.015357 -0.098144 -0.030257  0.004565   -0.028087
# 296     -0.094815       0.031447 -0.040429 -0.173176 -0.031357    0.235188
# 297     -0.039226       0.006915 -0.021440  0.098243  0.249433   -0.084452
# 298      0.021458      -0.117484  0.299413 -0.095095  0.108865    0.031053
# 299     -0.001357      -0.032845  0.165557 -0.095092  0.123183    0.200369
#
# ...

# %%
df.nunique()
# Out:
# cabozantinib     300
# nakiterpiosin    300
# MST-312          300
# GSK4112          300
# ML258            300
#                 ...
# BRD-K02492147    300
# methotrexate     300
# importazole      300
# BRD-K45681478    300
# BMS-536924       300
# Length: 483, dtype: int64

# %%
ln = df['MST-312']
P = df['nakiterpiosin']
fig = plt.figure()
ax = fig.add_axes([0.1, 0.6, 2.5, 2.4])
ax.set_xlabel("MST-312")
ax.set_ylabel("nakiterpiosin")
ax.scatter(ln,P)

# %%
ln2 = df['MST-312']
P2 = df['GSK4112']
fig = plt.figure()
ax = fig.add_axes([0.1, 0.6, 2.5, 2.4])
ax.set_xlabel("MST-312")
ax.set_ylabel("GSK4112")
ax.scatter(ln2,P2)
