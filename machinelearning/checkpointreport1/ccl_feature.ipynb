# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"/Users/sadiaakther/Desktop/data_InSummary 2/Drug_response/ccle/ccl_feature.csv")
df
# Out:
#          LN18      769P      786O     CAOV3     HEPG2     MOLT4   NCIH524  \
# 0   -0.376446 -0.495240 -0.627470 -0.791327  0.091280  2.181840  1.053044
# 1   -0.964646 -0.168022 -0.525237  0.553917  0.509613 -0.385591 -0.586602
# 2   -0.234786 -0.290195 -0.614989  0.020523  0.541487 -0.296633  2.868671
# 3    0.186366  0.959644  0.483978 -0.893287  2.342748 -0.704963 -0.815153
# 4   -1.033155 -1.292583 -1.364322 -0.471442 -0.000251 -0.757418 -0.813339
# ..        ...       ...       ...       ...       ...       ...       ...
# 295  1.507423 -0.218756  0.317995  0.634288 -0.802512  0.183736  1.248639
# 296  0.762414  0.005374  1.407402  1.787903 -0.623199  0.722665 -0.407574
# 297 -0.678130 -0.499138 -0.300512  0.115527 -1.467306 -0.077250  0.769035
# 298 -0.311646  1.172551 -0.319554  1.436225 -0.604639 -0.631630  0.216005
# 299 -0.677978  0.282346 -0.457093  1.237488  0.815533 -0.137978 -0.414109
#
#       NCIH209  MIAPACA2      MCAS  ...     SLR21    LNZ308     LN340  \
# ...

# %%
df.columns
# Out:
# Index(['LN18', '769P', '786O', 'CAOV3', 'HEPG2', 'MOLT4', 'NCIH524', 'NCIH209',
#        'MIAPACA2', 'MCAS',
#        ...
#        'SLR21', 'LNZ308', 'LN340', 'HCC827GR5', 'SLR20', 'HK2', 'EW8',
#        'UOK101', 'JHESOAD1', 'CH157MN'],
#       dtype='object', length=1037)

# %%
df.head(7)
# Out:
#        LN18      769P      786O     CAOV3     HEPG2     MOLT4   NCIH524  \
# 0 -0.376446 -0.495240 -0.627470 -0.791327  0.091280  2.181840  1.053044
# 1 -0.964646 -0.168022 -0.525237  0.553917  0.509613 -0.385591 -0.586602
# 2 -0.234786 -0.290195 -0.614989  0.020523  0.541487 -0.296633  2.868671
# 3  0.186366  0.959644  0.483978 -0.893287  2.342748 -0.704963 -0.815153
# 4 -1.033155 -1.292583 -1.364322 -0.471442 -0.000251 -0.757418 -0.813339
# 5 -0.510266 -1.513406 -1.362347  0.318208 -1.212947 -0.692430 -0.229966
# 6 -0.468020  2.183621  1.672562  0.229910  0.216527 -1.011669 -0.455447
#
#     NCIH209  MIAPACA2      MCAS  ...     SLR21    LNZ308     LN340  HCC827GR5  \
# 0  0.988874  0.096774 -0.708258  ... -0.936652 -0.273787 -0.667269  -0.529940
# 1  0.046361 -0.088911  1.319878  ...  0.101342 -1.016092 -1.506311   1.355457
# 2  3.119790  0.120674 -0.795678  ... -0.213099  0.261673  0.100384  -0.403081
# 3 -1.234851  0.755110 -0.315366  ...  0.679143  0.290043  0.476173   0.029773
# ...

# %%
df.shape
# Out:
# (300, 1037)

# %%
df.isnull().sum()
# Out:
# LN18        0
# 769P        0
# 786O        0
# CAOV3       0
# HEPG2       0
#            ..
# HK2         0
# EW8         0
# UOK101      0
# JHESOAD1    0
# CH157MN     0
# Length: 1037, dtype: int64

# %%
df.nunique()
# Out:
# LN18        300
# 769P        300
# 786O        300
# CAOV3       300
# HEPG2       300
#            ...
# HK2         300
# EW8         300
# UOK101      300
# JHESOAD1    300
# CH157MN     300
# Length: 1037, dtype: int64

# %%
df.count()
df.describe()
# Out:
#              LN18        769P        786O       CAOV3       HEPG2       MOLT4  \
# count  300.000000  300.000000  300.000000  300.000000  300.000000  300.000000
# mean    -0.040586   -0.022876   -0.091688    0.045748   -0.011588   -0.030297
# std      0.905906    0.775061    0.757514    1.074941    1.214716    0.769266
# min     -2.653554   -2.232101   -2.008515   -2.431933   -3.425825   -3.651655
# 25%     -0.612089   -0.470813   -0.552201   -0.682347   -0.805869   -0.486192
# 50%     -0.101180    0.008208   -0.122198    0.038326    0.077821   -0.063117
# 75%      0.608002    0.431541    0.366165    0.757595    0.735451    0.427602
# max      2.277023    2.183621    2.131685    2.988682    3.504770    3.145111
#
#           NCIH524     NCIH209    MIAPACA2        MCAS  ...       SLR21  \
# count  300.000000  300.000000  300.000000  300.000000  ...  300.000000
# mean     0.005499   -0.046155   -0.078641   -0.050955  ...    0.026263
# ...

# %%
LN = df['LN18']
Kidney= df['769P']
fig = plt.figure()
ax = fig.add_axes([0.1, 0.6, 2.5, 2.4])
ax.set_xlabel("LN18")
ax.set_ylabel("769P")
ax.scatter(LN,Kidney)
